# %% [markdown]
# <a href="https://colab.research.google.com/github/FLafage/Cours_Python/blob/main/Bienvenue_dans_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Premier cours de Pyhton avec François
